# %% [markdown]
# # RAG with ChatGPT
# Retrieval Augmented Generation using FAISS indexing

# %%
#!pip install faiss-cpu

# %%
#!pip install openai

# %%
#!pip install numpy==1.24.3
#!pip install pandas

# %%
#!pip install --upgrade bottleneck

# %%
import pandas as pd

# %%
import faiss
import numpy as np

# %%
#import openai
from openai import OpenAI
client = OpenAI()

# %%
# List of files for multiple years
files = {
    2021: '/Users/cg1123/Desktop/New Technologies/Gen AI/RAG/data/individual/2021.csv',
    2022: '/Users/cg1123/Desktop/New Technologies/Gen AI/RAG/data/individual/2022.csv',
    2023: '/Users/cg1123/Desktop/New Technologies/Gen AI/RAG/data/individual/2023.csv',
    2024: '/Users/cg1123/Desktop/New Technologies/Gen AI/RAG/data/individual/2024.csv'
}

# %%
# Function to create tagged summaries
def create_tagged_summary(row):
    return (
        f"Season: {row['season']}, City: {row['city']}, Date: {row['date']}, "
        f"Match Type: {row['match_type']}, Player of the Match: {row['player_of_match']}, "
        f"Venue: {row['venue']}, Team1: {row['team1']}, Team2: {row['team2']}, "
        f"Toss Winner: {row['toss_winner']}, Toss Decision: {row['toss_decision']}, "
        f"Winner: {row['winner']}, Result: {row['result']} by {row['result_margin']} runs/wickets, "
        f"Super Over: {row['super_over']}, Umpires: {row['umpire1']} and {row['umpire2']}."
    )

# %%
# Process each file
processed_data = {}
for year, file_path in files.items():
    # Load the CSV file
    data = pd.read_csv(file_path)
    # Generate tagged summaries
    data['summary'] = data.apply(create_tagged_summary, axis=1)
    processed_data[year] = data

# %%
processed_data[2021].head(1)
# Out:
#           id  season     city        date match_type player_of_match  \
# 0  1254058.0  2021.0  Chennai  09/04/2021     League        HV Patel
#
#                                       venue           team1  \
# 0  MA Chidambaram Stadium, Chepauk, Chennai  Mumbai Indians
#
#                          team2                  toss_winner  ...  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore  ...
#
#                         winner   result result_margin  target_runs  \
# 0  Royal Challengers Bangalore  wickets           2.0        160.0
#
#    target_overs  super_over method                umpire1      umpire2  \
# 0          20.0           N    NaN  KN Ananthapadmanabhan  Nitin Menon
#
#                                              summary
# 0  Season: 2021.0, City: Chennai, Date: 09/04/202...
#
# [1 rows x 21 columns]

# %%
# Function to generate embeddings using OpenAI client.embeddings.create
def get_embedding(text, model="text-embedding-ada-002"):
    response = client.embeddings.create(
        input=text,
        model=model
    )
    return response.data[0].embedding

# %%
test_text = "How many matches did CSK lose?"
test_embedding = get_embedding(test_text)
print(test_embedding)
# Out:
# [-0.0013754806714132428, -0.0032734812702983618, 0.03143583983182907, 0.020249679684638977, -0.053130995482206345, 0.014454755932092667, -0.005664701573550701, -0.0016815047711133957, -0.013647372834384441, -0.024312637746334076, 0.020666394382715225, 0.018322380259633064, -0.018595848232507706, 0.0028128172270953655, -0.010782466270029545, 0.0014943091664463282, 0.00723388884216547, -0.015613740310072899, 0.018179133534431458, -0.013647372834384441, -0.035550884902477264, 0.007800359278917313, -0.016251834109425545, -0.0010792233
# %%
# Process each year's data
for year, data in processed_data.items():
    print(f"Processing embeddings for {year}...")
    
    # Generate embeddings for each match summary
    embeddings = [get_embedding(summary) for summary in data['summary']]
    
    # Save embeddings to FAISS
    embedding_dim = len(embeddings[0])
    index = faiss.IndexFlatL2(embedding_dim)
    index.add(np.array(embeddings))
    faiss.write_index(index, f"/Users/cg1123/Desktop/New Technologies/Gen AI/RAG/data/processed/{year}_embeddings.index")
    
    # Save the processed data with summaries
    data.to_csv(f"/Users/cg1123/Desktop/New Technologies/Gen AI/RAG/data/processed/{year}_processed.csv", index=False)
# Out:
# Processing embeddings for 2021...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 6
#       3 print(f"Processing embeddings for {year}...")
#       5 # Generate embeddings for each match summary
# ----> 6 embeddings = [get_embedding(summary) for summary in data['summary']]
#       8 # Save embeddings to FAISS
#       9 embedding_dim = len(embeddings[0])
#
# Cell In[72], line 6, in <listcomp>(.0)
#       3 print(f"Processing embeddings for {year}...")
#       5 # Generate embeddings for each match summary
# ----> 6 embeddings = [get_embedding(summary) for summary in data['summary']]
#       8 # Save embeddings to FAISS
#       9 embedding_dim = len(embeddings[0])
#
# Cell In[70], line 3, in get_embedding(text, model)
#       2 def get_embedding(text, model="text-embedding-ada-002"):
# ----> 3     response = client.embeddings.create(
#       4         input=text,
#       5         model=model
#       6     )
#       7     return response.data[0].embedding
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/resources/embeddings.py:124, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     118         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     119             base64.b64decode(data), dtype="float32"
#     120         ).tolist()
#     122     return obj
# --> 124 return self._post(
#     125     "/embeddings",
#     126     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     127     options=make_request_options(
#     128         extra_headers=extra_headers,
#     129         extra_query=extra_query,
#     130         extra_body=extra_body,
#     131         timeout=timeout,
#     132         post_parser=parser,
#     133     ),
#     134     cast_to=CreateEmbeddingResponse,
#     135 )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1280, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1266 def post(
#    1267     self,
#    1268     path: str,
#    (...)
#    1275     stream_cls: type[_StreamT] | None = None,
#    1276 ) -> ResponseT | _StreamT:
#    1277     opts = FinalRequestOptions.construct(
#    1278         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1279     )
# -> 1280     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:957, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     954 else:
#     955     retries_taken = 0
# --> 957 return self._request(
#     958     cast_to=cast_to,
#     959     options=options,
#     960     stream=stream,
#     961     stream_cls=stream_cls,
#     962     retries_taken=retries_taken,
#     963 )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:993, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     990 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     992 try:
# --> 993     response = self._client.send(
#     994         request,
#     995         stream=stream or self._should_stream_response_body(request=request),
#     996         **kwargs,
#     997     )
#     998 except httpx.TimeoutException as err:
#     999     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1292     if flags != 0:
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#    1298     return super().recv(buflen, flags)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1167         return self._sslobj.read(len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#    1171     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# # Above is the configuration
# Below is the runtime code for queries

# %%
# Function to query matches from multiple years
def query_matches(query, team=None, years=None, top_k=35):
    query_embedding = get_embedding(query)
    results = []

    # Filter years if specified
    if years:
        selected_files = {year: file for year, file in files.items() if year in years}
    else:
        selected_files = files

    for year, file_path in selected_files.items():
        print(f"Searching matches from {year}...")
        
        # Load the FAISS index and data
        index = faiss.read_index(f"/Users/cg1123/Desktop/New Technologies/Gen AI/RAG/data/processed/{year}_embeddings.index")
        data = pd.read_csv(f"/Users/cg1123/Desktop/New Technologies/Gen AI/RAG/data/processed/{year}_processed.csv")
        
        # Search the index
        distances, indices = index.search(np.array([query_embedding]), k=top_k)
        retrieved_matches = data.iloc[indices[0]]

        # Filter by team if specified
        if team:
            retrieved_matches = retrieved_matches[
                (retrieved_matches['team1'] == team) | (retrieved_matches['team2'] == team)
            ]

        # Add results to the list
        for _, row in retrieved_matches.iterrows():
            results.append({
                "year": year,
                "date": row['date'],
                "match_type": row['match_type'],
                "venue": row['venue'],
                "team1": row['team1'],
                "team2": row['team2'],
                "winner": row['winner'],
                "result": f"{row['result']} by {row['result_margin']} runs/wickets"
            })

    return results

# %%
# Function to format context for ChatGPT
def generate_chatgpt_response(query, results):
    # Format retrieved matches into a readable context
    context = "\n".join([
        f"Year: {match['year']}, Date: {match['date']}, Match_Type: {match['match_type']}, Venue: {match['venue']}, "
        f"{match['team1']} vs {match['team2']}, Winner: {match['winner']}, Result: {match['result']}."
        for match in results
    ])
    
    # Prompt to ChatGPT
    prompt = (
        f"The following information is relevant to the query:\n{context}\n\n"
        f"Now, answer the question: {query}"
    )
    
    # Call ChatGPT to generate the response
    response = client.chat.completions.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You are an IPL analyst."},
            {"role": "user", "content": prompt}
        ]
    )
    
    return response.choices[0].message.content

# %%
# Example query
query = "Summarise the second SRH vs LSG match in 2024 for me"
results = query_matches(query,  years=[2024]) #team="Sunrisers Hyderabad",

# Display results
for match in results:
    print(f"Year: {match['year']}, Date: {match['date']}, Venue: {match['venue']}, "
          f"{match['team1']} vs {match['team2']}, Winner: {match['winner']}, Result: {match['result']}")
# Out:
# Searching matches from 2024...
# Year: 2024, Date: 02/05/2024, Venue: Rajiv Gandhi International Stadium, Uppal, Hyderabad, Sunrisers Hyderabad vs Rajasthan Royals, Winner: Sunrisers Hyderabad, Result: runs by 1 runs/wickets
# Year: 2024, Date: 08/05/2024, Venue: Rajiv Gandhi International Stadium, Uppal, Hyderabad, Lucknow Super Giants vs Sunrisers Hyderabad, Winner: Sunrisers Hyderabad, Result: wickets by 10 runs/wickets
# Year: 2024, Date: 19/05/2024, Venue: Rajiv Gandhi International Stadium, Uppal, Hyderabad, Punjab Kings vs Sunrisers Hyderabad, Winner: Sunrisers Hyderabad, Result: wickets by 4 runs/wickets
# Year: 2024, Date: 05/04/2024, Venue: Rajiv Gandhi International Stadium, Uppal, Hyderabad, Chennai Super Kings vs Sunrisers Hyderabad, Winner: Sunrisers Hyderabad, Result: wickets by 6 runs/wickets
# Year: 2024, Date: 12/05/2024, Venue: M Chinnaswamy Stadium, Bengaluru, Royal Challengers Bengaluru vs Delhi Capitals, Winner: Royal Challengers Bengaluru, Result: runs by 47 runs/wickets

# %%
# Generate and display ChatGPT's response
if results:
    response = generate_chatgpt_response(query, results)
    print(response)
else:
    print("No relevant matches found.")
# Out:
# The second match between Sunrisers Hyderabad (SRH) and Lucknow Super Giants (LSG) in the year 2024 took place on 08/05/2024. The match type was a league match and it was held at the Rajiv Gandhi International Stadium in Uppal, Hyderabad. Sunrisers Hyderabad emerged as the winner of the match by chasing the target set by Lucknow Super Giants. They won by a margin of 10 wickets.

# %%
query = ""
while(query!="done"):
    query = input("please type your query followed by enter(type \"done\" if you are finished):\n")
    
    if(query!="done"):
        q_team = None
        q_years = None
        
        q_team_raw = input("Enter team you would like to focus on (optional): ")
        if(len(q_team_raw)>0):
            q_team = q_team_raw
        
        q_years_raw = input("Enter specific years from 2021-2024, separated by comma: (optional)")
        if(len(q_years_raw)>0):
            q_years = [int(year) for year in q_years_raw.split(",")]
            
        #print(q_team,q_years)
        results = query_matches(query, team=q_team, years=q_years)
        print("Retrieved data for query:\n")
        for match in results:
            print(f"Year: {match['year']}, Date: {match['date']}, Match_Type: {match['match_type']}, Venue: {match['venue']}, "f"{match['team1']} vs {match['team2']}, Winner: {match['winner']}, Result: {match['result']}")
        if results:
            response = generate_chatgpt_response(query, results)
            print(response)
        else:
            print("No relevant matches found. Cannot perform RAG.")
# Out:
# please type your query followed by enter(type "done" if you are finished):
# What is the greatest margin of victory in IPL 2024?
# Enter team you would like to focus on (optional):
# Enter specific years from 2021-2024, separated by comma: (optional)2024
# Searching matches from 2024...
# Retrieved data for query:
#
# Year: 2024, Date: 14/05/2024, Match_Type: League, Venue: Arun Jaitley Stadium, Delhi, Delhi Capitals vs Lucknow Super Giants, Winner: Delhi Capitals, Result: runs by 19 runs/wickets
# Year: 2024, Date: 03/05/2024, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Kolkata Knight Riders vs Mumbai Indians, Winner: Kolkata Knight Riders, Result: runs by 24 runs/wickets
# Year: 2024, Date: 27/04/2024, Match_Type: League, Venue: Arun Jaitley Stadium, Delhi, Delhi Capitals vs Mumbai Indians, Winner: Delhi Capitals, Result: runs by 10 runs/wickets
# Year: 2024, Date: 22/04/2024, Match_Type: League, Venue: Sawai Mansingh Stadium, Jaipur, Mumbai Indians vs Rajasthan Royals, Winner: Rajasthan Royals, Result: wickets by 9 runs/wickets
# Year: 2024, Date: 20/04/2024, Match_Type: League, Venue: Arun Jaitley Stadium, Delhi, Sunrisers Hyderabad vs Delhi Capitals, Winner: Sunrisers Hyderabad, Result: runs by 67 runs/wickets
# Year: 2024, Date: 14/04/2024, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Chennai Super Kings vs Mumbai Indians, Winner: Chennai Super Kings, Result: runs by 20 runs/wickets
# The greatest margin of victory in IPL 2024 is by 78 runs, achieved by Chennai Super Kings against Sunrisers Hyderabad on 28/04/2024 at MA Chidambaram Stadium, Chepauk, Chennai.
# please type your query followed by enter(type "done" if you are finished):
# Which team performed the worst in IPL?
# Enter team you would like to focus on (optional):
# Enter specific years from 2021-2024, separated by comma: (optional)
# Searching matches from 2021...
# Searching matches from 2022...
# Searching matches from 2023...
# Searching matches from 2024...
# Retrieved data for query:
#
# Year: 2021, Date: 01/05/2021, Match_Type: League, Venue: Arun Jaitley Stadium, Delhi, Chennai Super Kings vs Mumbai Indians, Winner: Mumbai Indians, Result: wickets by 4.0 runs/wickets
# Year: 2021, Date: 29/04/2021, Match_Type: League, Venue: Arun Jaitley Stadium, Delhi, Rajasthan Royals vs Mumbai Indians, Winner: Mumbai Indians, Result: wickets by 7.0 runs/wickets
# Year: 2021, Date: 22/04/2021, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Rajasthan Royals vs Royal Challengers Bangalore, Winner: Royal Challengers Bangalore, Result: wickets by 10.0 runs/wickets
# Year: 2021, Date: 25/04/2021, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Chennai Super Kings vs Royal Challengers Bangalore, Winner: Chennai Super Kings, Result: runs by 69.0 runs/wickets
# Year: 2021, Date: 28/04/2021, Match_Type: League, Venue: Arun Jaitley Stadium, Delhi, Sunrisers Hyderabad vs Chennai Super Kings, Winner: Chennai Super Kings, Result: wickets by 7.0 runs/wickets
# Year: 2021, Date: 02/05/2021, Match_Type: League, Venue: Arun Jaitley Stadium, Delhi, Rajasthan Royals vs Sunrisers Hyderabad, Winner: Rajasthan Royals, Result: runs by 55.0 runs/wickets
# Year: 2021, Date: 21/04/2021, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Chennai Super Kings vs Kolkata Knight Riders, Winner: Chennai Super Kings, Result: runs by 18.0 runs/wickets
# Year: 2021, Date: 09/04/2021, Match_Type: League, Venue: MA Chidambaram Stadium, Chepauk, Chennai, Mumbai Indians vs Royal Challengers Bangalore, Winner: Royal Challengers Bangalore, Result: wickets by 2.0 runs/wickets
# Year: 2021, Date: 02/10/2021, Match_Type: League, Venue: Sharjah Cricket Stadium, Mumbai Indians vs Delhi Capitals, Winner: Delhi Capitals, Result: wickets by 4.0 runs/wickets
# Year: 2021, Date: 04/10/2021, Match_Type: League, Venue: Dubai International Cricket Stadium, Chennai Super Kings vs Delhi Capitals, Winner: Delhi Capitals, Result: wickets by 3.0 runs/wickets
# Year: 2021, Date: 16/04/2021, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Punjab Kings vs Chennai Super Kings, Winner: Chennai Super Kings, Result: wickets by 6.0 runs/wickets
# Year: 2021, Date: 15/04/2021, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Delhi Capitals vs Rajasthan Royals, Winner: Rajasthan Royals, Result: wickets by 3.0 runs/wickets
# Year: 2023, Date: 30/04/2023, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Rajasthan Royals vs Mumbai Indians, Winner: Mumbai Indians, Result: wickets by 6.0 runs/wickets
# Year: 2023, Date: 02/04/2023, Match_Type: League, Venue: M Chinnaswamy Stadium, Bengaluru, Mumbai Indians vs Royal Challengers Bangalore, Winner: Royal Challengers Bangalore, Result: wickets by 8.0 runs/wickets
# Year: 2023, Date: 07/05/2023, Match_Type: League, Venue: Sawai Mansingh Stadium, Jaipur, Rajasthan Royals vs Sunrisers Hyderabad, Winner: Sunrisers Hyderabad, Result: wickets by 4.0 runs/wickets
# Year: 2023, Date: 27/04/2023, Match_Type: League, Venue: Sawai Mansingh Stadium, Jaipur, Rajasthan Royals vs Chennai Super Kings, Winner: Rajasthan Royals, Result: runs by 32.0 runs/wickets
# Year: 2023, Date: 10/04/2023, Match_Type: League, Venue: M Chinnaswamy Stadium, Bengaluru, Royal Challengers Bangalore vs Lucknow Super Giants, Winner: Lucknow Super Giants, Result: wickets by 1.0 runs/wickets
# Year: 2023, Date: 06/05/2023, Match_Type: League, Venue: Arun Jaitley Stadium, Delhi, Royal Challengers Bangalore vs Delhi Capitals, Winner: Delhi Capitals, Result: wickets by 7.0 runs/wickets
# Year: 2023, Date: 16/04/2023, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Kolkata Knight Riders vs Mumbai Indians, Winner: Mumbai Indians, Result: wickets by 5.0 runs/wickets
# Year: 2023, Date: 14/05/2023, Match_Type: League, Venue: Sawai Mansingh Stadium, Jaipur, Royal Challengers Bangalore vs Rajasthan Royals, Winner: Royal Challengers Bangalore, Result: runs by 112.0 runs/wickets
# Year: 2023, Date: 19/04/2023, Match_Type: League, Venue: Sawai Mansingh Stadium, Jaipur, Lucknow Super Giants vs Rajasthan Royals, Winner: Lucknow Super Giants, Result: runs by 10.0 runs/wickets
# Year: 2023, Date: 11/05/2023, Match_Type: League, Venue: Eden Gardens, Kolkata, Kolkata Knight Riders vs Rajasthan Royals, Winner: Rajasthan Royals, Result: wickets by 9.0 runs/wickets
# Year: 2023, Date: 09/05/2023, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Royal Challengers Bangalore vs Mumbai Indians, Winner: Mumbai Indians, Result: wickets by 6.0 runs/wickets
# Year: 2023, Date: 08/04/2023, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Mumbai Indians vs Chennai Super Kings, Winner: Chennai Super Kings, Result: wickets by 7.0 runs/wickets
# Year: 2023, Date: 21/05/2023, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Sunrisers Hyderabad vs Mumbai Indians, Winner: Mumbai Indians, Result: wickets by 8.0 runs/wickets
# Year: 2023, Date: 05/05/2023, Match_Type: League, Venue: Sawai Mansingh Stadium, Jaipur, Rajasthan Royals vs Gujarat Titans, Winner: Gujarat Titans, Result: wickets by 9.0 runs/wickets
# Year: 2023, Date: 20/05/2023, Match_Type: League, Venue: Eden Gardens, Kolkata, Lucknow Super Giants vs Kolkata Knight Riders, Winner: Lucknow Super Giants, Result: runs by 1.0 runs/wickets
# Year: 2023, Date: 22/04/2023, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Punjab Kings vs Mumbai Indians, Winner: Punjab Kings, Result: runs by 13.0 runs/wickets
# Year: 2023, Date: 03/05/2023, Match_Type: League, Venue: Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh, Punjab Kings vs Mumbai Indians, Winner: Mumbai Indians, Result: wickets by 6.0 runs/wickets
# Year: 2023, Date: 20/05/2023, Match_Type: League, Venue: Arun Jaitley Stadium, Delhi, Chennai Super Kings vs Delhi Capitals, Winner: Chennai Super Kings, Result: runs by 77.0 runs/wickets
# Year: 2023, Date: 08/04/2023, Match_Type: League, Venue: Barsapara Cricket Stadium, Guwahati, Rajasthan Royals vs Delhi Capitals, Winner: Rajasthan Royals, Result: runs by 57.0 runs/wickets
# Year: 2023, Date: 11/04/2023, Match_Type: League, Venue: Arun Jaitley Stadium, Delhi, Delhi Capitals vs Mumbai Indians, Winner: Mumbai Indians, Result: wickets by 6.0 runs/wickets
# Year: 2023, Date: 04/04/2023, Match_Type: League, Venue: Arun Jaitley Stadium, Delhi, Delhi Capitals vs Gujarat Titans, Winner: Gujarat Titans, Result: wickets by 6.0 runs/wickets
# Year: 2023, Date: 12/05/2023, Match_Type: League, Venue: Wankhede Stadium, Mumbai, Mumbai Indians vs Gujarat Titans, Winner: Mumbai Indians, Result: runs by 27.0 runs/wickets
# Year: 2023, Date: 18/04/2023, Match_Type: League, Venue: Rajiv Gandhi International Stadium, Uppal, Hyderabad, Mumbai Indians vs Sunrisers Hyderabad, Winner: Mumbai Indians, Result: runs by 14.0 runs/wickets
# Year: 2023, Date: 01/05/2023, Match_Type: League, Venue: Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow, Royal Challengers Bangalore vs Lucknow Super Giants, Winner: Royal Challengers Bangalore, Result: runs by 18.0 runs/wickets
# Year: 2023, Date: 23/04/2023, Match_Type: League, Venue: M Chinnaswamy Stadium, Bengaluru, Royal Challengers Bangalore vs Rajasthan Royals, Winner: Royal Challengers Bangalore, Result: runs by 7.0 runs/wickets
# Year: 2023, Date: 19/05/2023, Match_Type: League, Venue: Himachal Pradesh Cricket Association Stadium, Dharamsala, Punjab Kings vs Rajasthan Royals, Winner: Rajasthan Royals, Result: wickets by 4.0 runs/wickets
# Year: 2023, Date: 29/04/2023, Match_Type: League, Venue: Eden Gardens, Kolkata, Kolkata Knight Riders vs Gujarat Titans, Winner: Gujarat Titans, Result: wickets by 7.0 runs/wickets
# Year: 2023, Date: 29/04/2023, Match_Type: League, Venue: Arun Jaitley Stadium, Delhi, Sunrisers Hyderabad vs Delhi Capitals, Winner: Sunrisers Hyderabad, Result: runs by 9.0 runs/wickets
# Year: 2023, Date: 20/04/2023, Match_Type: League, Venue: Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh, Royal Challengers Bangalore vs Punjab Kings, Winner: Royal Challengers Bangalore, Result: runs by 24.0 runs/wickets
